# %%
import pdb


def swap(l, a, b):
    temp = l[a]
    l[a] = l[b]
    l[b] = temp


def shift_elements(a, s, e, p):
#     pdb.set_trace()

    if s >= e:
        return
    assert s <= p <= e, "Invalid Pivot"
    assert s < e, f"Invalid start: {s} and end: {e}. Must have Start<=End."
    c = 0
    i = 0
    bp = p
    while i < p:
        if a[i] > a[p]:
            a.insert(e+1, a[i])
            del a[i]
            p -= 1
            bp -= 1
            c += 1
        elif a[i] == a[p]:
            swap(a, i, p - 1)
            p -= 1
        else:
            i += 1
    left_end = p

    i = -c + e
    # i = -1 + e
    p = bp
#     pdb.set_trace()
    while i > p:
        if a[i] < a[p]:
            a.insert(s, a[i])
            del a[i + 1]
            p += 1
        elif a[i] == a[p]:
            swap(a, i, p + 1)
            p += 1
        else:
            i -= 1

    left_end += p - bp
    left_start = s
    right_end = e
    right_start = p

    left_end -= 1
    right_start += 1
    shift_elements(a, left_start, left_end, left_start + (left_end - left_start) // 2)
    shift_elements(
        a, right_start, right_end, right_start + (right_end - right_start) // 2
    )

    return a


def sol(l):
    return shift_elements(l, 0, len(l) - 1, len(l) // 2)

# %%
def extra_space_sol(a):
    if not a:
        return []
    p = a[len(a) // 2]
    return extra_space_sol([i for i in a if i < p]) + [i for i in a if i == p] + extra_space_sol([i for i in a if i > p])

# %%
a = [7, 2, 4, 6, 4, 0, 9, 0, 3, 0]

# %%
extra_space_sol(a)
# Out:
# [0, 0, 0, 2, 3, 4, 4, 6, 7, 9]

# %%
shift_elements(a, 0, 9, 4)
# Out:
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) !a
# [2, 4, 4, 0, 9, 0, 3, 0, 7, 6]
# (Pdb) !i
# 7
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !a
# [0, 0, 3, 0, 2, 4, 4, 9, 7, 6]
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) !s
# 0
# (Pdb) !s
# 0
# (Pdb) !p
# 2
# (Pdb) !e
# 4
# (Pdb) !i
# 4
# (Pdb) ll
#  10  	def shift_elements(a, s, e, p):
#  11  	    pdb.set_trace()
#  12
#  13  	    if s >= e:
#  14  	        return
#  15  	    assert s <= p <= e, "Invalid Pivot"
#  16  	    assert s < e, f"Invalid start: {s} and end: {e}. Must have Start<=End."
#  17  	    c = 0
#  18  	    i = 0
#  19  	    bp = p
#  20  	    while i < p:
#  21  	        if a[i] > a[p]:
#  22  	            a.insert(e+1, a[i])
#  23  	            del a[i]
#  24  	            p -= 1
#  25  	            bp -= 1
#  26  	            c += 1
#  27  	        elif a[i] == a[p]:
#  28  	            swap(a, i, p - 1)
#  29  	            p -= 1
#  30  	        else:
#  31  	            i += 1
#  32  	    left_end = p
#  33
#  34  	    i = -c + e
#  35  	    # i = -1 + e
#  36  	    p = bp
#  37  	    pdb.set_trace()
#  38  ->	    while i > p:
#  39  	        if a[i] < a[p]:
#  40  	            a.insert(s, a[i])
#  41  	            del a[i + 1]
#  42  	            p += 1
#  43  	        elif a[i] == a[p]:
#  44  	            swap(a, i, p + 1)
#  45  	            p += 1
#  46  	        else:
#  47  	            i -= 1
#  48
#  49  	    left_end += p - bp
#  50  	    left_start = s
#  51  	    right_end = e
#  52  	    right_start = p
#  53
#  54  	    left_end -= 1
#  55  	    right_start += 1
#  56  	    shift_elements(a, left_start, left_end, left_start + (left_end - left_start) // 2)
#  57  	    shift_elements(
#  58  	        a, right_start, right_end, right_start + (right_end - right_start) // 2
#  59  	    )
#  60
#  61  	    return a
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(39)shift_elements()
# -> if a[i] < a[p]:
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(40)shift_elements()
# -> a.insert(s, a[i])
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(41)shift_elements()
# -> del a[i + 1]
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(42)shift_elements()
# -> p += 1
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) !a
# [2, 0, 0, 3, 0, 4, 4, 9, 7, 6]
# (Pdb) !i
# 4
# (Pdb) !p
# 3
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(39)shift_elements()
# -> if a[i] < a[p]:
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(40)shift_elements()
# -> a.insert(s, a[i])
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(41)shift_elements()
# -> del a[i + 1]
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(42)shift_elements()
# -> p += 1
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) !i
# 4
# (Pdb) !p
# 4
# (Pdb) n
# > <ipython-input-6-4b27952c7288>(49)shift_elements()
# -> left_end += p - bp
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !a
# [0, 2, 0, 0, 3, 4, 4, 9, 7, 6]
# (Pdb) !s
# 0
# (Pdb) !e
# 3
# (Pdb) !p
# 1
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) !a
# [0, 2, 0, 0, 3, 4, 4, 9, 7, 6]
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !a
# [0, 0, 0, 2, 3, 4, 4, 9, 7, 6]
# (Pdb) !s
# 0
# (Pdb) !e
# 2
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !a
# [0, 0, 0, 2, 3, 4, 4, 9, 7, 6]
# (Pdb) !s
# 0
# (Pdb) !e
# 0
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !s
# 4
# (Pdb) !e
# 3
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !s
# 7
# (Pdb) !e
# 9
# (Pdb) !a
# [0, 0, 0, 2, 3, 4, 4, 9, 7, 6]
# (Pdb) !p
# 8
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(38)shift_elements()
# -> while i > p:
# (Pdb) !a
# [0, 0, 0, 2, 3, 4, 4, 7, 6, 9]
# (Pdb) !i
# 8
# (Pdb) !p
# 7
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !a
# [0, 0, 0, 2, 3, 4, 4, 6, 7, 9]
# (Pdb) !s
# 7
# (Pdb) !e
# 7
# (Pdb) c
# > <ipython-input-6-4b27952c7288>(13)shift_elements()
# -> if s >= e:
# (Pdb) !a
# [0, 0, 0, 2, 3, 4, 4, 6, 7, 9]
# (Pdb) !s
# 9
# (Pdb) !e
# 9
# (Pdb) c
# [0, 0, 0, 2, 3, 4, 4, 6, 7, 9]

# %%
sol(a)
# Out:
# [0, 0, 0, 2, 3, 4, 4, 6, 7, 9]
